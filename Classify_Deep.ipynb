# %% [markdown]
# <a href="https://colab.research.google.com/github/HYUNSOOLEE-6839/colab-Deep-Learning/blob/main/Classify_Deep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # VGG16

# %%
# !unzip -qq animal.zip -d animals

# %%
# !ls
# Out:
# animal	animals  animal.zip  sample_data

# %%
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
vgg = VGG16()
vgg.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
import numpy as np
from PIL import Image

# %%
vgg16_list3 = []

for file in os.listdir('animals'):
    full_path = 'animals/' + file
    
    image = load_img(full_path, target_size=(224, 224))
    image = img_to_array(image)
    image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
    image = preprocess_input(image)
    yhat = vgg.predict(image.reshape(-1,224,224,3))
    label = decode_predictions(yhat)
    label = label[0][0]
    vgg16_list3.append(label[2])

# %% [markdown]
# ### 데이터프레임으로 정리

# %%
import pandas as pd

# %%
df = pd.DataFrame(vgg16_list)
df2 = pd.DataFrame(vgg16_list2)
df3 = pd.DataFrame(vgg16_list3)

# %%
animal = pd.concat([df, df2, df3], axis=1)

# %%
animal.columns=["origin", "VGG16_pred", "VGG16_acc"]
animal
# Out:
#       origin        VGG16_pred  VGG16_acc
# 0     판다.jpg       giant_panda   0.999923
# 1     늑대.jpg            coyote   0.977185
# 2     수달.jpg             otter   0.994292
# 3    참새2.jpg       house_finch   0.325445
# 4    펠리컨.jpg           pelican   0.998832
# 5    다람쥐.jpg      fox_squirrel   0.968472
# 6    호랑이.jpg             tiger   0.721879
# 7    거북이.jpg        loggerhead   0.692404
# 8     기린.jpg           gazelle   0.239202
# 9     참새.jpg     ruffed_grouse   0.279991
# 10    여우.jpg           kit_fox   0.442117
# 11   독수리.jpg        bald_eagle   0.999983
# 12   코알라.jpg             koala   0.999988
# 13   앵무새.jpg          lorikeet   0.958426
# 14  청둥오리.jpg             drake   0.999732
# 15   코끼리.jpg  African_elephant   0.854488
# 16   키위새.jpg            beaver   0.342196
# 17   비둘기.jpg         ptarmigan   0.619744
# 18     양.jpg               ram   0.995033
# 19   얼룩말.jpg             zebra   0.999355
# 20   너구리.jpg      lesser_panda   0.157891
# ...

# %% [markdown]
# # VGG19

# %%
from tensorflow.keras.applications.vgg19 import VGG19

# %%
vgg19 = VGG19()
vgg19.summary()
# Out:
# ...
# 574717952/574710816 [==============================] - 4s 0us/step
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# ...

# %%
vgg19_list3 = []

for file in os.listdir('animals'):
    full_path = 'animals/' + file
    
    image = load_img(full_path, target_size=(224, 224))
    image = img_to_array(image)
    image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
    image = preprocess_input(image)
    yhat = vgg19.predict(image.reshape(-1,224,224,3))
    label = decode_predictions(yhat)
    label = label[0][0]
    vgg19_list3.append(label[2])

# %% [markdown]
# ### 데이터프레임으로 정리

# %%
vgg19_df = pd.DataFrame(vgg19_list)
vgg19_df2 = pd.DataFrame(vgg19_list2)
vgg19_df3 = pd.DataFrame(vgg19_list3)

# %%
vgg19_animal = pd.concat([vgg19_df, vgg19_df2, vgg19_df3], axis=1)

# %%
vgg19_animal.columns=["origin", "VGG19_pred", "VGG19_acc"]
vgg19_animal
# Out:
#       origin           VGG19_pred  VGG19_acc
# 0     판다.jpg          giant_panda   0.999845
# 1     늑대.jpg               coyote   0.927308
# 2     수달.jpg                otter   0.980756
# 3    참새2.jpg                quail   0.503044
# 4    펠리컨.jpg              pelican   0.999485
# 5    다람쥐.jpg         fox_squirrel   0.998267
# 6    호랑이.jpg                tiger   0.736542
# 7    거북이.jpg           loggerhead   0.938913
# 8     기린.jpg  African_hunting_dog   0.256859
# 9     참새.jpg            ptarmigan   0.542078
# 10    여우.jpg         Egyptian_cat   0.553038
# 11   독수리.jpg           bald_eagle   0.999985
# 12   코알라.jpg                koala   0.999960
# 13   앵무새.jpg             lorikeet   0.997285
# 14  청둥오리.jpg                drake   0.998833
# 15   코끼리.jpg     African_elephant   0.790914
# 16   키위새.jpg               beaver   0.428291
# 17   비둘기.jpg            partridge   0.299307
# 18     양.jpg                  ram   0.982837
# 19   얼룩말.jpg                zebra   0.999382
# ...

# %% [markdown]
# # RESNET

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
resnet = ResNet50()
resnet.summary()
# Out:
# ...
# 102973440/102967424 [==============================] - 1s 0us/step
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_3[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# ...

# %%
res_list3 = []

for file in os.listdir('animals'):
    full_path = 'animals/' + file
    
    image = load_img(full_path, target_size=(224, 224))
    image = img_to_array(image)
    image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
    image = preprocess_input(image)
    yhat = resnet.predict(image.reshape(-1,224,224,3))
    label = decode_predictions(yhat)
    label = label[0][0]
    res_list3.append(label[2])

# %%
res_df = pd.DataFrame(res_list)
res_df2 = pd.DataFrame(res_list2)
res_df3 = pd.DataFrame(res_list3)

# %%
res_animal = pd.concat([res_df, res_df2, res_df3], axis=1)

# %%
res_animal.columns=["origin", "pred", "RES_acc"]
res_animal
# Out:
#       origin              pred   RES_acc
# 0     판다.jpg       giant_panda  0.997970
# 1     늑대.jpg            coyote  0.889749
# 2     수달.jpg             otter  0.995877
# 3    참새2.jpg         brambling  0.385245
# 4    펠리컨.jpg           pelican  0.999608
# 5    다람쥐.jpg      fox_squirrel  0.927461
# 6    호랑이.jpg             tiger  0.957994
# 7    거북이.jpg        loggerhead  0.588102
# 8     기린.jpg           gazelle  0.631569
# 9     참새.jpg         partridge  0.337320
# 10    여우.jpg           kit_fox  0.625879
# 11   독수리.jpg        bald_eagle  0.999866
# 12   코알라.jpg             koala  0.999292
# 13   앵무새.jpg          lorikeet  0.659314
# 14  청둥오리.jpg             drake  0.946679
# 15   코끼리.jpg  African_elephant  0.796302
# 16   키위새.jpg            beaver  0.700853
# 17   비둘기.jpg         ptarmigan  0.425647
# 18     양.jpg               ram  0.275171
# 19   얼룩말.jpg             zebra  0.999166
# 20   너구리.jpg          grey_fox  0.215504
# 21    까치.jpg            magpie  0.924478

# %% [markdown]
# # ResNet50 V2

# %%
from tensorflow.keras.applications.resnet_v2 import ResNet50V2
res2 = ResNet50V2()
res2.summary()
# Out:
# Model: "resnet50v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_6 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_6[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# ...

# %%
res2_list3 = []

for file in os.listdir('animals'):
    full_path = 'animals/' + file
    
    image = load_img(full_path, target_size=(224, 224))
    image = img_to_array(image)
    image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
    image = preprocess_input(image)
    yhat = res2.predict(image.reshape(-1,224,224,3))
    label = decode_predictions(yhat)
    label = label[0][0]
    res2_list3.append(label[2])

# %%
res2_df = pd.DataFrame(res2_list)
res2_df2 = pd.DataFrame(res2_list2)
res2_df3 = pd.DataFrame(res2_list3)

# %%
res2_animal = pd.concat([res2_df, res2_df2, res2_df3], axis=1)

# %%
res2_animal.columns=["origin", "RES2_pred", "RES2_acc"]
res2_animal
# Out:
#       origin         RES2_pred  RES2_acc
# 0     판다.jpg  English_foxhound  1.000000
# 1     늑대.jpg  English_foxhound  1.000000
# 2     수달.jpg  English_foxhound  1.000000
# 3    참새2.jpg  English_foxhound  1.000000
# 4    펠리컨.jpg  English_foxhound  1.000000
# 5    다람쥐.jpg      fox_squirrel  1.000000
# 6    호랑이.jpg  English_foxhound  1.000000
# 7    거북이.jpg            trifle  1.000000
# 8     기린.jpg           bow_tie  1.000000
# 9     참새.jpg  English_foxhound  0.999867
# 10    여우.jpg      fox_squirrel  0.981265
# 11   독수리.jpg      fox_squirrel  1.000000
# 12   코알라.jpg  English_foxhound  1.000000
# 13   앵무새.jpg      fox_squirrel  1.000000
# 14  청둥오리.jpg         ice_lolly  0.982230
# 15   코끼리.jpg      fox_squirrel  0.848745
# 16   키위새.jpg      fox_squirrel  1.000000
# 17   비둘기.jpg  English_foxhound  1.000000
# 18     양.jpg      fox_squirrel  1.000000
# 19   얼룩말.jpg            trifle  0.999903
# 20   너구리.jpg      fox_squirrel  1.000000
# 21    까치.jpg  English_foxhound  0.999307

# %%
Classify_animal = pd.merge(merge_outer, res2_animal, how="outer", on="origin")
# Out:
#       origin        VGG16_pred  VGG16_acc  ...   RES_acc         RES2_pred  RES2_acc
# 0     판다.jpg       giant_panda   0.999923  ...  0.997970  English_foxhound  1.000000
# 1     늑대.jpg            coyote   0.977185  ...  0.889749  English_foxhound  1.000000
# 2     수달.jpg             otter   0.994292  ...  0.995877  English_foxhound  1.000000
# 3    참새2.jpg       house_finch   0.325445  ...  0.385245  English_foxhound  1.000000
# 4    펠리컨.jpg           pelican   0.998832  ...  0.999608  English_foxhound  1.000000
# 5    다람쥐.jpg      fox_squirrel   0.968472  ...  0.927461      fox_squirrel  1.000000
# 6    호랑이.jpg             tiger   0.721879  ...  0.957994  English_foxhound  1.000000
# 7    거북이.jpg        loggerhead   0.692404  ...  0.588102            trifle  1.000000
# 8     기린.jpg           gazelle   0.239202  ...  0.631569           bow_tie  1.000000
# 9     참새.jpg     ruffed_grouse   0.279991  ...  0.337320  English_foxhound  0.999867
# ...

# %%
Classify_animal.columns=["Origin","VGG16_pred", "VGG16_acc", "VGG19_pred", "VGG19_acc", "RES_pred", "RES_acc", "RES2_pred", "RES2_acc"]

# %%
Classify_animal.set_index('Origin')
# Out:
#                 VGG16_pred  VGG16_acc  ...         RES2_pred  RES2_acc
# Origin                                 ...
# 판다.jpg         giant_panda   0.999923  ...  English_foxhound  1.000000
# 늑대.jpg              coyote   0.977185  ...  English_foxhound  1.000000
# 수달.jpg               otter   0.994292  ...  English_foxhound  1.000000
# 참새2.jpg        house_finch   0.325445  ...  English_foxhound  1.000000
# 펠리컨.jpg            pelican   0.998832  ...  English_foxhound  1.000000
# 다람쥐.jpg       fox_squirrel   0.968472  ...      fox_squirrel  1.000000
# 호랑이.jpg              tiger   0.721879  ...  English_foxhound  1.000000
# 거북이.jpg         loggerhead   0.692404  ...            trifle  1.000000
# 기린.jpg             gazelle   0.239202  ...           bow_tie  1.000000
# 참새.jpg       ruffed_grouse   0.279991  ...  English_foxhound  0.999867
# 여우.jpg             kit_fox   0.442117  ...      fox_squirrel  0.981265
# 독수리.jpg         bald_eagle   0.999983  ...      fox_squirrel  1.000000
# ...
