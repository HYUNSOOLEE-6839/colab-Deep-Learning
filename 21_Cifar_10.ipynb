# %% [markdown]
# <a href="https://colab.research.google.com/github/HYUNSOOLEE-6839/colab-Deep-Learning/blob/main/21_Cifar_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cifar-10 이미지 분류

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Flatten, Dropout, Activation
import os
import numpy as np

# %%
# 실행할 때 마다 같은 결과를 출력하기 위한 seed 값 설정
seed = 2021
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
# 나중에 지정될 변수의 값을 미리 세팅
BATCH_SIZE = 32
NUM_CLASSES = 10
EPOCHS = 100
DATA_AUGMENTATION = True
NUM_PREDICTIONS = 20
SAVE_DIR = os.path.join(os.getcwd(), 'model')
MODEL_NAME = 'keras_cifar10_trained_model.h5'

# %%
     # The data, split between train and test sets:
     (x_train, y_train0), (x_test, y_test0) = cifar10.load_data()
     print('x_train shape:', x_train.shape)
     print(x_train.shape[0], 'train samples')
     print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ### 데이터 확인

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

plt.subplot(141)
plt.imshow(x_train[0], interpolation="bicubic")
plt.grid(False)
plt.subplot(142)
plt.imshow(x_train[4], interpolation="bicubic")
plt.grid(False)
plt.subplot(143)
plt.imshow(x_train[8], interpolation="bicubic")
plt.grid(False)
plt.subplot(144)
plt.imshow(x_train[12], interpolation="bicubic")
plt.grid(False)

# %% [markdown]
# ### 자료형을 실수로 변환한 후 정규화

# %%
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %%
# One-hot encoding
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train0, NUM_CLASSES)
y_test = to_categorical(y_test0, NUM_CLASSES)
y_train.shape, y_test.shape
# Out:
# ((50000, 10), (10000, 10))

# %% [markdown]
# ### 모델 정의/설정/학습

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), padding='same', input_shape=x_train.shape[1:], activation='relu'))
model.add(Conv2D(32, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3, 3), padding='same', input_shape=x_train.shape[1:], activation='relu'))
model.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, input_dim=784, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(NUM_CLASSES, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1180160
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
# initiate RMSprop optimzer
from tensorflow.keras.optimizers import RMSprop
opt=RMSprop(learning_rate=0.0001, decay=1e-6)

# %%
model.compile(loss='categorical_crossentropy', 
              optimizer=opt, metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
modelpath = "model/cifar10-cnn-{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

# %%
history = model.fit(x_train, y_train, validation_split=0.2, epochs=EPOCHS, batch_size=BATCH_SIZE, shuffle=True, callbacks=[checkpointer, early_stopping_callback])
# Out:
# Epoch 1/100
# 1250/1250 [==============================] - 9s 5ms/step - loss: 2.0559 - accuracy: 0.2359 - val_loss: 1.6249 - val_accuracy: 0.4185
#
# Epoch 00001: val_loss improved from inf to 1.62491, saving model to model/cifar10-cnn-01-1.6249.hdf5
# Epoch 2/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.6155 - accuracy: 0.4064 - val_loss: 1.4861 - val_accuracy: 0.4623
#
# Epoch 00002: val_loss improved from 1.62491 to 1.48607, saving model to model/cifar10-cnn-02-1.4861.hdf5
# Epoch 3/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.4530 - accuracy: 0.4726 - val_loss: 1.3631 - val_accuracy: 0.5213
#
# Epoch 00003: val_loss improved from 1.48607 to 1.36311, saving model to model/cifar10-cnn-03-1.3631.hdf5
# Epoch 4/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.3619 - accuracy: 0.5099 - val_loss: 1.2432 - val_accuracy: 0.5689
#
# Epoch 00004: val_loss improved from 1.36311 to 1.24325, saving model to model/cifar10-cnn-04-1.2432.hdf5
# Epoch 5/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.2930 - accuracy: 0.5369 - val_loss: 1.2729 - val_accuracy: 0.5538
#
# Epoch 00005: val_loss did not improve from 1.24325
# Epoch 6/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.2267 - accuracy: 0.5670 - val_loss: 1.1482 - val_accuracy: 0.5974
#
# Epoch 00006: val_loss improved from 1.24325 to 1.14822, saving model to model/cifar10-cnn-06-1.1482.hdf5
# Epoch 7/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1564 - accuracy: 0.5903 - val_loss: 1.0732 - val_accuracy: 0.6244
#
# Epoch 00007: val_loss improved from 1.14822 to 1.07318, saving model to model/cifar10-cnn-07-1.0732.hdf5
# Epoch 8/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1183 - accuracy: 0.6069 - val_loss: 1.0274 - val_accuracy: 0.6440
#
# Epoch 00008: val_loss improved from 1.07318 to 1.02741, saving model to model/cifar10-cnn-08-1.0274.hdf5
# Epoch 9/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0676 - accuracy: 0.6240 - val_loss: 1.0179 - val_accuracy: 0.6436
#
# Epoch 00009: val_loss improved from 1.02741 to 1.01785, saving model to model/cifar10-cnn-09-1.0179.hdf5
# Epoch 10/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.0297 - accuracy: 0.6398 - val_loss: 0.9398 - val_accuracy: 0.6765
#
# Epoch 00010: val_loss improved from 1.01785 to 0.93975, saving model to model/cifar10-cnn-10-0.9398.hdf5
# Epoch 11/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9842 - accuracy: 0.6545 - val_loss: 0.9331 - val_accuracy: 0.6712
#
# Epoch 00011: val_loss improved from 0.93975 to 0.93305, saving model to model/cifar10-cnn-11-0.9331.hdf5
# Epoch 12/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9553 - accuracy: 0.6643 - val_loss: 0.8984 - val_accuracy: 0.6884
#
# Epoch 00012: val_loss improved from 0.93305 to 0.89839, saving model to model/cifar10-cnn-12-0.8984.hdf5
# Epoch 13/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9375 - accuracy: 0.6721 - val_loss: 0.9125 - val_accuracy: 0.6847
#
# Epoch 00013: val_loss did not improve from 0.89839
# Epoch 14/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.9088 - accuracy: 0.6850 - val_loss: 0.8871 - val_accuracy: 0.6918
#
# Epoch 00014: val_loss improved from 0.89839 to 0.88714, saving model to model/cifar10-cnn-14-0.8871.hdf5
# Epoch 15/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8842 - accuracy: 0.6923 - val_loss: 0.8544 - val_accuracy: 0.7033
#
# Epoch 00015: val_loss improved from 0.88714 to 0.85443, saving model to model/cifar10-cnn-15-0.8544.hdf5
# Epoch 16/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8620 - accuracy: 0.7008 - val_loss: 0.8343 - val_accuracy: 0.7106
#
# Epoch 00016: val_loss improved from 0.85443 to 0.83432, saving model to model/cifar10-cnn-16-0.8343.hdf5
# Epoch 17/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8381 - accuracy: 0.7091 - val_loss: 0.8023 - val_accuracy: 0.7219
#
# Epoch 00017: val_loss improved from 0.83432 to 0.80230, saving model to model/cifar10-cnn-17-0.8023.hdf5
# Epoch 18/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8123 - accuracy: 0.7203 - val_loss: 0.7868 - val_accuracy: 0.7278
#
# Epoch 00018: val_loss improved from 0.80230 to 0.78676, saving model to model/cifar10-cnn-18-0.7868.hdf5
# Epoch 19/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.8127 - accuracy: 0.7207 - val_loss: 0.7866 - val_accuracy: 0.7302
#
# Epoch 00019: val_loss improved from 0.78676 to 0.78657, saving model to model/cifar10-cnn-19-0.7866.hdf5
# Epoch 20/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7820 - accuracy: 0.7318 - val_loss: 0.7587 - val_accuracy: 0.7406
#
# Epoch 00020: val_loss improved from 0.78657 to 0.75872, saving model to model/cifar10-cnn-20-0.7587.hdf5
# Epoch 21/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7792 - accuracy: 0.7304 - val_loss: 0.7676 - val_accuracy: 0.7371
#
# Epoch 00021: val_loss did not improve from 0.75872
# Epoch 22/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7716 - accuracy: 0.7344 - val_loss: 0.7330 - val_accuracy: 0.7474
#
# Epoch 00022: val_loss improved from 0.75872 to 0.73298, saving model to model/cifar10-cnn-22-0.7330.hdf5
# Epoch 23/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7547 - accuracy: 0.7379 - val_loss: 0.7416 - val_accuracy: 0.7454
#
# Epoch 00023: val_loss did not improve from 0.73298
# Epoch 24/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7469 - accuracy: 0.7400 - val_loss: 0.7297 - val_accuracy: 0.7512
#
# Epoch 00024: val_loss improved from 0.73298 to 0.72974, saving model to model/cifar10-cnn-24-0.7297.hdf5
# Epoch 25/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7335 - accuracy: 0.7501 - val_loss: 0.7157 - val_accuracy: 0.7555
#
# Epoch 00025: val_loss improved from 0.72974 to 0.71574, saving model to model/cifar10-cnn-25-0.7157.hdf5
# Epoch 26/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7217 - accuracy: 0.7500 - val_loss: 0.7144 - val_accuracy: 0.7586
#
# Epoch 00026: val_loss improved from 0.71574 to 0.71440, saving model to model/cifar10-cnn-26-0.7144.hdf5
# Epoch 27/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7310 - accuracy: 0.7522 - val_loss: 0.7164 - val_accuracy: 0.7537
#
# Epoch 00027: val_loss did not improve from 0.71440
# Epoch 28/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7153 - accuracy: 0.7553 - val_loss: 0.7156 - val_accuracy: 0.7554
#
# Epoch 00028: val_loss did not improve from 0.71440
# Epoch 29/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7118 - accuracy: 0.7584 - val_loss: 0.7039 - val_accuracy: 0.7578
#
# Epoch 00029: val_loss improved from 0.71440 to 0.70386, saving model to model/cifar10-cnn-29-0.7039.hdf5
# Epoch 30/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7012 - accuracy: 0.7630 - val_loss: 0.7277 - val_accuracy: 0.7556
#
# Epoch 00030: val_loss did not improve from 0.70386
# Epoch 31/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.7025 - accuracy: 0.7608 - val_loss: 0.7031 - val_accuracy: 0.7629
#
# Epoch 00031: val_loss improved from 0.70386 to 0.70309, saving model to model/cifar10-cnn-31-0.7031.hdf5
# Epoch 32/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6900 - accuracy: 0.7626 - val_loss: 0.7188 - val_accuracy: 0.7650
#
# Epoch 00032: val_loss did not improve from 0.70309
# Epoch 33/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6920 - accuracy: 0.7626 - val_loss: 0.7023 - val_accuracy: 0.7632
#
# Epoch 00033: val_loss improved from 0.70309 to 0.70227, saving model to model/cifar10-cnn-33-0.7023.hdf5
# Epoch 34/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6885 - accuracy: 0.7675 - val_loss: 0.7028 - val_accuracy: 0.7671
#
# Epoch 00034: val_loss did not improve from 0.70227
# Epoch 35/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6844 - accuracy: 0.7674 - val_loss: 0.6804 - val_accuracy: 0.7709
#
# Epoch 00035: val_loss improved from 0.70227 to 0.68041, saving model to model/cifar10-cnn-35-0.6804.hdf5
# Epoch 36/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6734 - accuracy: 0.7741 - val_loss: 0.6750 - val_accuracy: 0.7736
#
# Epoch 00036: val_loss improved from 0.68041 to 0.67503, saving model to model/cifar10-cnn-36-0.6750.hdf5
# Epoch 37/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6689 - accuracy: 0.7737 - val_loss: 0.7056 - val_accuracy: 0.7635
#
# Epoch 00037: val_loss did not improve from 0.67503
# Epoch 38/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6766 - accuracy: 0.7693 - val_loss: 0.6822 - val_accuracy: 0.7708
#
# Epoch 00038: val_loss did not improve from 0.67503
# Epoch 39/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6613 - accuracy: 0.7752 - val_loss: 0.6823 - val_accuracy: 0.7727
#
# Epoch 00039: val_loss did not improve from 0.67503
# Epoch 40/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6613 - accuracy: 0.7774 - val_loss: 0.6977 - val_accuracy: 0.7729
#
# Epoch 00040: val_loss did not improve from 0.67503
# Epoch 41/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6719 - accuracy: 0.7746 - val_loss: 0.6856 - val_accuracy: 0.7740
#
# Epoch 00041: val_loss did not improve from 0.67503
# Epoch 42/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6599 - accuracy: 0.7801 - val_loss: 0.6978 - val_accuracy: 0.7664
#
# Epoch 00042: val_loss did not improve from 0.67503
# Epoch 43/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6598 - accuracy: 0.7778 - val_loss: 0.6691 - val_accuracy: 0.7766
#
# Epoch 00043: val_loss improved from 0.67503 to 0.66905, saving model to model/cifar10-cnn-43-0.6691.hdf5
# Epoch 44/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6587 - accuracy: 0.7753 - val_loss: 0.7387 - val_accuracy: 0.7574
#
# Epoch 00044: val_loss did not improve from 0.66905
# Epoch 45/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6488 - accuracy: 0.7790 - val_loss: 0.6747 - val_accuracy: 0.7736
#
# Epoch 00045: val_loss did not improve from 0.66905
# Epoch 46/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6444 - accuracy: 0.7826 - val_loss: 0.6989 - val_accuracy: 0.7689
#
# Epoch 00046: val_loss did not improve from 0.66905
# Epoch 47/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6485 - accuracy: 0.7833 - val_loss: 0.6615 - val_accuracy: 0.7789
#
# Epoch 00047: val_loss improved from 0.66905 to 0.66147, saving model to model/cifar10-cnn-47-0.6615.hdf5
# Epoch 48/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6389 - accuracy: 0.7852 - val_loss: 0.6574 - val_accuracy: 0.7823
#
# Epoch 00048: val_loss improved from 0.66147 to 0.65739, saving model to model/cifar10-cnn-48-0.6574.hdf5
# Epoch 49/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6390 - accuracy: 0.7855 - val_loss: 0.6659 - val_accuracy: 0.7773
#
# Epoch 00049: val_loss did not improve from 0.65739
# Epoch 50/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6415 - accuracy: 0.7872 - val_loss: 0.6494 - val_accuracy: 0.7858
#
# Epoch 00050: val_loss improved from 0.65739 to 0.64936, saving model to model/cifar10-cnn-50-0.6494.hdf5
# Epoch 51/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6412 - accuracy: 0.7829 - val_loss: 0.6674 - val_accuracy: 0.7747
#
# Epoch 00051: val_loss did not improve from 0.64936
# Epoch 52/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6281 - accuracy: 0.7934 - val_loss: 0.6954 - val_accuracy: 0.7686
#
# Epoch 00052: val_loss did not improve from 0.64936
# Epoch 53/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6214 - accuracy: 0.7916 - val_loss: 0.6777 - val_accuracy: 0.7789
#
# Epoch 00053: val_loss did not improve from 0.64936
# Epoch 54/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6326 - accuracy: 0.7902 - val_loss: 0.6598 - val_accuracy: 0.7834
#
# Epoch 00054: val_loss did not improve from 0.64936
# Epoch 55/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6373 - accuracy: 0.7864 - val_loss: 0.6514 - val_accuracy: 0.7844
#
# Epoch 00055: val_loss did not improve from 0.64936
# Epoch 56/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6153 - accuracy: 0.7995 - val_loss: 0.6670 - val_accuracy: 0.7792
#
# Epoch 00056: val_loss did not improve from 0.64936
# Epoch 57/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6188 - accuracy: 0.7955 - val_loss: 0.6794 - val_accuracy: 0.7818
#
# Epoch 00057: val_loss did not improve from 0.64936
# Epoch 58/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6297 - accuracy: 0.7877 - val_loss: 0.6370 - val_accuracy: 0.7866
#
# Epoch 00058: val_loss improved from 0.64936 to 0.63696, saving model to model/cifar10-cnn-58-0.6370.hdf5
# Epoch 59/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6196 - accuracy: 0.7934 - val_loss: 0.6609 - val_accuracy: 0.7819
#
# Epoch 00059: val_loss did not improve from 0.63696
# Epoch 60/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6316 - accuracy: 0.7919 - val_loss: 0.6785 - val_accuracy: 0.7854
#
# Epoch 00060: val_loss did not improve from 0.63696
# Epoch 61/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6165 - accuracy: 0.7937 - val_loss: 0.6847 - val_accuracy: 0.7768
#
# Epoch 00061: val_loss did not improve from 0.63696
# Epoch 62/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6065 - accuracy: 0.7973 - val_loss: 0.6372 - val_accuracy: 0.7894
#
# Epoch 00062: val_loss did not improve from 0.63696
# Epoch 63/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6125 - accuracy: 0.7954 - val_loss: 0.6993 - val_accuracy: 0.7748
#
# Epoch 00063: val_loss did not improve from 0.63696
# Epoch 64/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6100 - accuracy: 0.8000 - val_loss: 0.6387 - val_accuracy: 0.7904
#
# Epoch 00064: val_loss did not improve from 0.63696
# Epoch 65/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6137 - accuracy: 0.7942 - val_loss: 0.6342 - val_accuracy: 0.7893
#
# Epoch 00065: val_loss improved from 0.63696 to 0.63418, saving model to model/cifar10-cnn-65-0.6342.hdf5
# Epoch 66/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6045 - accuracy: 0.7984 - val_loss: 0.6846 - val_accuracy: 0.7720
#
# Epoch 00066: val_loss did not improve from 0.63418
# Epoch 67/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6059 - accuracy: 0.7999 - val_loss: 0.6575 - val_accuracy: 0.7884
#
# Epoch 00067: val_loss did not improve from 0.63418
# Epoch 68/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6084 - accuracy: 0.7967 - val_loss: 0.6725 - val_accuracy: 0.7866
#
# Epoch 00068: val_loss did not improve from 0.63418
# Epoch 69/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6170 - accuracy: 0.7992 - val_loss: 0.6534 - val_accuracy: 0.7833
#
# Epoch 00069: val_loss did not improve from 0.63418
# Epoch 70/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6071 - accuracy: 0.7973 - val_loss: 0.6601 - val_accuracy: 0.7893
#
# Epoch 00070: val_loss did not improve from 0.63418
# Epoch 71/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6026 - accuracy: 0.7981 - val_loss: 0.6515 - val_accuracy: 0.7870
#
# Epoch 00071: val_loss did not improve from 0.63418
# Epoch 72/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6017 - accuracy: 0.7998 - val_loss: 0.6766 - val_accuracy: 0.7853
#
# Epoch 00072: val_loss did not improve from 0.63418
# Epoch 73/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6010 - accuracy: 0.8020 - val_loss: 0.6523 - val_accuracy: 0.7938
#
# Epoch 00073: val_loss did not improve from 0.63418
# Epoch 74/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.5951 - accuracy: 0.8032 - val_loss: 0.6472 - val_accuracy: 0.7903
#
# Epoch 00074: val_loss did not improve from 0.63418
# Epoch 75/100
# 1250/1250 [==============================] - 6s 5ms/step - loss: 0.6005 - accuracy: 0.7992 - val_loss: 0.6856 - val_accuracy: 0.7839
#
# Epoch 00075: val_loss did not improve from 0.63418

# %%
from tensorflow.keras.models import load_model

best_model = load_model('./model/cifar10-cnn-65-0.6342.hdf5')
acc = best_model.evaluate(x_test, y_test, verbose=1)[1]
print(f"\n Test Accuracy:{acc:.4f}")
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6435 - accuracy: 0.7845
#
#  Test Accuracy:0.7845

# %% [markdown]
# ### 훈련과정 시각화

# %%
# 검증셋의 오차
# y_loss에 테스트셋으로 실험 결과의 오차 값을 저장
y_loss=history.history['loss']
# y_loss에 테스트셋으로 실험 결과의 오차 값을 저장
y_vloss=history.history['val_loss']
# y_acc에 테스트셋으로 실험 결과의 오차 값을 저장
y_acc=history.history['accuracy']

# %%
x_len = np.arange(1, len(y_loss)+1)
plt.figure(figsize=(8,6))
plt.plot(x_len, y_vloss, marker=".", c="red", label='Validationset_loss')
plt.plot(x_len, y_loss, marker=".", c="blue", label='Trainset_loss')
plt.grid()
plt.legend(loc='upper right')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
x_len = np.arange(len(y_acc))
plt.figure(figsize=(12,8))
plt.plot(x_len, y_loss, "o-", c="red", label='Trainset_loss', markersize=5)
plt.plot(x_len, y_acc, "o-", c="blue", label='Trainset_accuracy', markersize=5)
plt.grid()
plt.legend(loc='upper right')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.show()
plt.show()
