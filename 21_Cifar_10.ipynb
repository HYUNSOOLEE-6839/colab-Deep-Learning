# %% [markdown]
# <a href="https://colab.research.google.com/github/HYUNSOOLEE-6839/colab-Deep-Learning/blob/main/21_Cifar_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cifar-10 이미지 분류

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Flatten, Dropout, Activation
import os
import numpy as np

# %%
# 실행할 때 마다 같은 결과를 출력하기 위한 seed 값 설정
seed = 2021
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
# 나중에 지정될 변수의 값을 미리 세팅
BATCH_SIZE = 32
NUM_CLASSES = 10
EPOCHS = 50
DATA_AUGMENTATION = True
NUM_PREDICTIONS = 20
SAVE_DIR = os.path.join(os.getcwd(), 'model')
MODEL_NAME = 'keras_cifar10_trained_model.h5'

# %%
     # The data, split between train and test sets:
     (x_train, y_train0), (x_test, y_test0) = cifar10.load_data()
     print('x_train shape:', x_train.shape)
     print(x_train.shape[0], 'train samples')
     print(x_test.shape[0], 'test samples')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ### 데이터 확인

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

plt.subplot(141)
plt.imshow(x_train[0], interpolation="bicubic")
plt.grid(False)
plt.subplot(142)
plt.imshow(x_train[4], interpolation="bicubic")
plt.grid(False)
plt.subplot(143)
plt.imshow(x_train[8], interpolation="bicubic")
plt.grid(False)
plt.subplot(144)
plt.imshow(x_train[12], interpolation="bicubic")
plt.grid(False)

# %% [markdown]
# ### 자료형을 실수로 변환한 후 정규화

# %%
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %%
# One-hot encoding
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train0, NUM_CLASSES)
y_test = to_categorical(y_test0, NUM_CLASSES)
y_train.shape, y_test.shape
# Out:
# ((50000, 10), (10000, 10))

# %% [markdown]
# ### 모델 정의/설정/학습

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), padding='same', input_shape=x_train.shape[1:], activation='relu'))
model.add(Conv2D(32, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3, 3), padding='same', input_shape=x_train.shape[1:], activation='relu'))
model.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, input_dim=784, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(NUM_CLASSES, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1180160
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
# initiate RMSprop optimzer
from tensorflow.keras.optimizers import RMSprop
opt=RMSprop(learning_rate=0.0001, decay=1e-6)

# %%
model.compile(loss='categorical_crossentropy', 
              optimizer=opt, metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
modelpath = "model/cifar10-cnn-{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

# %%
history = model.fit(x_train, y_train, validation_split=0.2, epochs=EPOCHS, batch_size=BATCH_SIZE, shuffle=True, callbacks=[checkpointer, early_stopping_callback])
# Out:
# Epoch 1/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 1.4699 - accuracy: 0.4684 - val_loss: 1.3643 - val_accuracy: 0.5162
#
# Epoch 00001: val_loss improved from 1.60190 to 1.36434, saving model to model/cifar10-cnn-01-1.3643.hdf5
# Epoch 2/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.3686 - accuracy: 0.5074 - val_loss: 1.3198 - val_accuracy: 0.5315
#
# Epoch 00002: val_loss improved from 1.36434 to 1.31980, saving model to model/cifar10-cnn-02-1.3198.hdf5
# Epoch 3/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.2906 - accuracy: 0.5397 - val_loss: 1.2279 - val_accuracy: 0.5700
#
# Epoch 00003: val_loss improved from 1.31980 to 1.22786, saving model to model/cifar10-cnn-03-1.2279.hdf5
# Epoch 4/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 1.2227 - accuracy: 0.5682 - val_loss: 1.1279 - val_accuracy: 0.6095
#
# Epoch 00004: val_loss improved from 1.22786 to 1.12790, saving model to model/cifar10-cnn-04-1.1279.hdf5
# Epoch 5/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 1.1579 - accuracy: 0.5912 - val_loss: 1.1455 - val_accuracy: 0.6023
#
# Epoch 00005: val_loss did not improve from 1.12790
# Epoch 6/50
# 1250/1250 [==============================] - 6s 5ms/step - loss: 1.1104 - accuracy: 0.6121 - val_loss: 1.0655 - val_accuracy: 0.6257
#
# Epoch 00006: val_loss improved from 1.12790 to 1.06554, saving model to model/cifar10-cnn-06-1.0655.hdf5
# Epoch 7/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 1.0648 - accuracy: 0.6271 - val_loss: 0.9884 - val_accuracy: 0.6535
#
# Epoch 00007: val_loss improved from 1.06554 to 0.98841, saving model to model/cifar10-cnn-07-0.9884.hdf5
# Epoch 8/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 1.0226 - accuracy: 0.6431 - val_loss: 0.9530 - val_accuracy: 0.6695
#
# Epoch 00008: val_loss improved from 0.98841 to 0.95300, saving model to model/cifar10-cnn-08-0.9530.hdf5
# Epoch 9/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.9875 - accuracy: 0.6556 - val_loss: 0.9657 - val_accuracy: 0.6612
#
# Epoch 00009: val_loss did not improve from 0.95300
# Epoch 10/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.9562 - accuracy: 0.6690 - val_loss: 0.8906 - val_accuracy: 0.6944
#
# Epoch 00010: val_loss improved from 0.95300 to 0.89065, saving model to model/cifar10-cnn-10-0.8906.hdf5
# Epoch 11/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.9300 - accuracy: 0.6769 - val_loss: 0.8907 - val_accuracy: 0.6833
#
# Epoch 00011: val_loss did not improve from 0.89065
# Epoch 12/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.9014 - accuracy: 0.6836 - val_loss: 0.8522 - val_accuracy: 0.7040
#
# Epoch 00012: val_loss improved from 0.89065 to 0.85216, saving model to model/cifar10-cnn-12-0.8522.hdf5
# Epoch 13/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.8810 - accuracy: 0.6934 - val_loss: 0.8525 - val_accuracy: 0.7056
#
# Epoch 00013: val_loss did not improve from 0.85216
# Epoch 14/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.8549 - accuracy: 0.7030 - val_loss: 0.8256 - val_accuracy: 0.7121
#
# Epoch 00014: val_loss improved from 0.85216 to 0.82555, saving model to model/cifar10-cnn-14-0.8256.hdf5
# Epoch 15/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.8381 - accuracy: 0.7091 - val_loss: 0.8216 - val_accuracy: 0.7119
#
# Epoch 00015: val_loss improved from 0.82555 to 0.82156, saving model to model/cifar10-cnn-15-0.8216.hdf5
# Epoch 16/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.8207 - accuracy: 0.7157 - val_loss: 0.7840 - val_accuracy: 0.7290
#
# Epoch 00016: val_loss improved from 0.82156 to 0.78396, saving model to model/cifar10-cnn-16-0.7840.hdf5
# Epoch 17/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.8084 - accuracy: 0.7208 - val_loss: 0.7676 - val_accuracy: 0.7353
#
# Epoch 00017: val_loss improved from 0.78396 to 0.76763, saving model to model/cifar10-cnn-17-0.7676.hdf5
# Epoch 18/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.7893 - accuracy: 0.7280 - val_loss: 0.7716 - val_accuracy: 0.7321
#
# Epoch 00018: val_loss did not improve from 0.76763
# Epoch 19/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.7800 - accuracy: 0.7325 - val_loss: 0.7510 - val_accuracy: 0.7430
#
# Epoch 00019: val_loss improved from 0.76763 to 0.75097, saving model to model/cifar10-cnn-19-0.7510.hdf5
# Epoch 20/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.7702 - accuracy: 0.7324 - val_loss: 0.7503 - val_accuracy: 0.7441
#
# Epoch 00020: val_loss improved from 0.75097 to 0.75026, saving model to model/cifar10-cnn-20-0.7503.hdf5
# Epoch 21/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.7559 - accuracy: 0.7391 - val_loss: 0.7472 - val_accuracy: 0.7435
#
# Epoch 00021: val_loss improved from 0.75026 to 0.74718, saving model to model/cifar10-cnn-21-0.7472.hdf5
# Epoch 22/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.7491 - accuracy: 0.7418 - val_loss: 0.7237 - val_accuracy: 0.7522
#
# Epoch 00022: val_loss improved from 0.74718 to 0.72370, saving model to model/cifar10-cnn-22-0.7237.hdf5
# Epoch 23/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.7397 - accuracy: 0.7448 - val_loss: 0.7330 - val_accuracy: 0.7452
#
# Epoch 00023: val_loss did not improve from 0.72370
# Epoch 24/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.7307 - accuracy: 0.7494 - val_loss: 0.7075 - val_accuracy: 0.7563
#
# Epoch 00024: val_loss improved from 0.72370 to 0.70748, saving model to model/cifar10-cnn-24-0.7075.hdf5
# Epoch 25/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.7240 - accuracy: 0.7538 - val_loss: 0.7074 - val_accuracy: 0.7564
#
# Epoch 00025: val_loss improved from 0.70748 to 0.70743, saving model to model/cifar10-cnn-25-0.7074.hdf5
# Epoch 26/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.7160 - accuracy: 0.7544 - val_loss: 0.7166 - val_accuracy: 0.7543
#
# Epoch 00026: val_loss did not improve from 0.70743
# Epoch 27/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.7137 - accuracy: 0.7596 - val_loss: 0.7127 - val_accuracy: 0.7551
#
# Epoch 00027: val_loss did not improve from 0.70743
# Epoch 28/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.7077 - accuracy: 0.7590 - val_loss: 0.7040 - val_accuracy: 0.7595
#
# Epoch 00028: val_loss improved from 0.70743 to 0.70401, saving model to model/cifar10-cnn-28-0.7040.hdf5
# Epoch 29/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.7031 - accuracy: 0.7616 - val_loss: 0.6878 - val_accuracy: 0.7638
#
# Epoch 00029: val_loss improved from 0.70401 to 0.68780, saving model to model/cifar10-cnn-29-0.6878.hdf5
# Epoch 30/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6988 - accuracy: 0.7639 - val_loss: 0.7278 - val_accuracy: 0.7535
#
# Epoch 00030: val_loss did not improve from 0.68780
# Epoch 31/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6908 - accuracy: 0.7639 - val_loss: 0.6881 - val_accuracy: 0.7677
#
# Epoch 00031: val_loss did not improve from 0.68780
# Epoch 32/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6850 - accuracy: 0.7657 - val_loss: 0.7093 - val_accuracy: 0.7611
#
# Epoch 00032: val_loss did not improve from 0.68780
# Epoch 33/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6821 - accuracy: 0.7687 - val_loss: 0.6876 - val_accuracy: 0.7683
#
# Epoch 00033: val_loss improved from 0.68780 to 0.68764, saving model to model/cifar10-cnn-33-0.6876.hdf5
# Epoch 34/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6736 - accuracy: 0.7729 - val_loss: 0.6908 - val_accuracy: 0.7652
#
# Epoch 00034: val_loss did not improve from 0.68764
# Epoch 35/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6707 - accuracy: 0.7737 - val_loss: 0.6848 - val_accuracy: 0.7672
#
# Epoch 00035: val_loss improved from 0.68764 to 0.68482, saving model to model/cifar10-cnn-35-0.6848.hdf5
# Epoch 36/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6706 - accuracy: 0.7756 - val_loss: 0.6592 - val_accuracy: 0.7784
#
# Epoch 00036: val_loss improved from 0.68482 to 0.65920, saving model to model/cifar10-cnn-36-0.6592.hdf5
# Epoch 37/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6617 - accuracy: 0.7770 - val_loss: 0.6863 - val_accuracy: 0.7685
#
# Epoch 00037: val_loss did not improve from 0.65920
# Epoch 38/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6611 - accuracy: 0.7768 - val_loss: 0.6757 - val_accuracy: 0.7695
#
# Epoch 00038: val_loss did not improve from 0.65920
# Epoch 39/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6531 - accuracy: 0.7814 - val_loss: 0.6660 - val_accuracy: 0.7775
#
# Epoch 00039: val_loss did not improve from 0.65920
# Epoch 40/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6555 - accuracy: 0.7776 - val_loss: 0.6833 - val_accuracy: 0.7757
#
# Epoch 00040: val_loss did not improve from 0.65920
# Epoch 41/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6513 - accuracy: 0.7821 - val_loss: 0.6765 - val_accuracy: 0.7728
#
# Epoch 00041: val_loss did not improve from 0.65920
# Epoch 42/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6490 - accuracy: 0.7815 - val_loss: 0.6884 - val_accuracy: 0.7690
#
# Epoch 00042: val_loss did not improve from 0.65920
# Epoch 43/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6420 - accuracy: 0.7846 - val_loss: 0.6675 - val_accuracy: 0.7756
#
# Epoch 00043: val_loss did not improve from 0.65920
# Epoch 44/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6450 - accuracy: 0.7839 - val_loss: 0.7220 - val_accuracy: 0.7613
#
# Epoch 00044: val_loss did not improve from 0.65920
# Epoch 45/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6367 - accuracy: 0.7869 - val_loss: 0.6544 - val_accuracy: 0.7783
#
# Epoch 00045: val_loss improved from 0.65920 to 0.65441, saving model to model/cifar10-cnn-45-0.6544.hdf5
# Epoch 46/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6386 - accuracy: 0.7863 - val_loss: 0.6932 - val_accuracy: 0.7657
#
# Epoch 00046: val_loss did not improve from 0.65441
# Epoch 47/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6312 - accuracy: 0.7878 - val_loss: 0.6919 - val_accuracy: 0.7702
#
# Epoch 00047: val_loss did not improve from 0.65441
# Epoch 48/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6291 - accuracy: 0.7897 - val_loss: 0.6557 - val_accuracy: 0.7821
#
# Epoch 00048: val_loss did not improve from 0.65441
# Epoch 49/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6257 - accuracy: 0.7875 - val_loss: 0.6552 - val_accuracy: 0.7800
#
# Epoch 00049: val_loss did not improve from 0.65441
# Epoch 50/50
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.6288 - accuracy: 0.7892 - val_loss: 0.6610 - val_accuracy: 0.7805
#
# Epoch 00050: val_loss did not improve from 0.65441

# %%
from tensorflow.keras.models import load_model

best_model = load_model('./model/cifar10-cnn-45-0.6544.hdf5')
acc = best_model.evaluate(x_test, y_test, verbose=1)[1]
print(f"\n Test Accuracy:{acc:.4f}")
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6624 - accuracy: 0.7793
#
#  Test Accuracy:0.7793

# %% [markdown]
# ### 훈련과정 시각화

# %%
# 검증셋의 오차
# y_loss에 테스트셋으로 실험 결과의 오차 값을 저장
y_loss=history.history['loss']
# y_loss에 테스트셋으로 실험 결과의 오차 값을 저장
y_vloss=history.history['val_loss']

# %%
x_len = np.arange(1, len(y_loss)+1)
plt.figure(figsize=(8,6))
plt.plot(x_len, y_vloss, marker=".", c="red", label='Validationset_loss')
plt.plot(x_len, y_loss, marker=".", c="blue", label='Trainset_loss')
plt.grid()
plt.legend(loc='upper right')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()
