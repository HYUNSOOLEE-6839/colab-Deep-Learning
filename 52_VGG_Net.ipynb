# %% [markdown]
# <a href="https://colab.research.google.com/github/HYUNSOOLEE-6839/colab-Deep-Learning/blob/main/52_VGG_Net.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # VGG Net

# %%
from tensorflow.keras.applications.vgg16 import VGG16, decode_predictions

# %%
# !unzip -qq animal.zip -d animal
# Out:
# 까치.jpg:  mismatching "local" filename (ъ╣Мь╣Ш.jpg),
#          continuing with "central" filename version
# 독수리.jpg:  mismatching "local" filename (ыПЕьИШыжм.jpg),
#          continuing with "central" filename version
# 비둘기.jpg:  mismatching "local" filename (ы╣ДыСШъ╕░.jpg),
#          continuing with "central" filename version
# 참새.jpg:  mismatching "local" filename (ь░╕ьГИ.jpg),
#          continuing with "central" filename version
# 참새2.jpg:  mismatching "local" filename (ь░╕ьГИ2.jpg),
#          continuing with "central" filename version

# %%
vgg = VGG16()
vgg.summary()
# Out:
# ...
# 553467904/553467096 [==============================] - 3s 0us/step
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# ...

# %%
import numpy as np
from PIL import Image

img = np.array(Image.open("animal/까치.jpg").resize((224,224)))

yhat = vgg.predict(img.reshape(-1,224,224,3))
label_key=np.argmax(yhat)
label=decode_predictions(yhat)
label = label[0][0]
print('%s(%.2f%%)'%(label[1], label[2]*100))
# Out:
# ...
# 40960/35363 [==================================] - 0s 0us/step
# coucal(42.34%)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = np.array(Image.open("animal/독수리.jpg").resize((224,224)))

yhat = vgg.predict(img.reshape(-1,224,224,3))
label_key=np.argmax(yhat)
label=decode_predictions(yhat)
label = label[0][0]
print('%s(%.2f%%)'%(label[1], label[2]*100))
# Out:
# bald_eagle(66.83%)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = np.array(Image.open("animal/참새2.jpg").resize((224,224)))

yhat = vgg.predict(img.reshape(-1,224,224,3))
label_key=np.argmax(yhat)
label=decode_predictions(yhat)
label = label[0][0]
print('%s(%.2f%%)'%(label[1], label[2]*100))
# Out:
# indigo_bunting(73.38%)
